# %% [markdown]
# # Types of Data
# Numerical Data
#
# Categorical Data

# %%
# import the library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('default')

# %% [markdown]
# Bivariate Analysis
#
# categorical -> numerical and numerical -> numerical
#
# Use case - Time series data

# %%
# Plotting s miple function
price =[48000, 54000, 57000, 49000, 47000, 45000]
year =[2015, 2016, 2017,2018, 2019,2020]

plt.plot(year, price)

# %%
# from a pandas dataframe 

batsman =pd.read_csv('sharma-kohli.csv')
batsman

plt.plot(batsman['index'], batsman['V Kohli'])

# %%
batsman.head()
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364

# %%
# plotting multiple plots
plt.plot(batsman['index'], batsman['V Kohli'])
plt.plot(batsman['index'], batsman['RG Sharma'])

# %%
# labels title

plt.plot(batsman['index'], batsman['V Kohli'])
plt.plot(batsman['index'], batsman['RG Sharma'])

plt.title('Rohit Sharma vs Virat Kohli Career Compresion')
plt.xlabel('Ipl Season')
plt.ylabel('Run Scored')
# Out:
# Text(0, 0.5, 'Run Scored')

# %%
# colors(hex) and line(width and style) and marker(size)
plt.plot(batsman['index'], batsman['V Kohli'] , color='#ecff33')
plt.plot(batsman['index'], batsman['RG Sharma'],  color='red')

plt.title('Rohit Sharma vs Virat Kohli Career Compresion')
plt.xlabel('Ipl Season')
plt.ylabel('Run Scored')
# Out:
# Text(0, 0.5, 'Run Scored')

# %%
plt.plot(batsman['index'], batsman['V Kohli'], color='#ecff33', linestyle='solid', linewidth=3)
plt.plot(batsman['index'], batsman['RG Sharma'], color='red', linestyle='dashdot', linewidth=2)

plt.title('Rohit Sharma vs Virat Kohli Career Comparison')
plt.xlabel('Index')
plt.ylabel('Runs')
plt.legend(['Virat Kohli', 'Rohit Sharma'])
plt.show()

# %%
plt.plot(batsman['index'], batsman['V Kohli'], color='#ecff33', linestyle='solid', linewidth=3, marker='D')
plt.plot(batsman['index'], batsman['RG Sharma'], color='red', linestyle='dashdot', linewidth=2, marker='o')

plt.title('Rohit Sharma vs Virat Kohli Career Comparison')
plt.xlabel('Index')
plt.ylabel('Runs')
plt.legend(['Virat Kohli', 'Rohit Sharma'])
plt.show()

# %%
# legend -> location 
plt.plot(batsman['index'], batsman['V Kohli'], color='#ecff33', linestyle='solid', linewidth=3,marker='D',markersize=10,label='Virat')
plt.plot(batsman['index'], batsman['RG Sharma'], color='red', linestyle='dashdot', linewidth=2, marker='o',label='Rohit')

plt.title('Rohit Sharma vs Virat Kohli Career Comparison')
plt.xlabel('Index')
plt.ylabel('Runs')
plt.legend(['Virat Kohli', 'Rohit Sharma'])
plt.show()

# %%
# limiting axes

# %%
# grid

# %%
# show
