# %%
# import libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Important things for Plotting
#
# 1. Data(df)
# 2. Type of Plot
# 3. x axis
# 4. y axis
# 5. grouping (hue/color) based on categorical varibale
# 6. size of the plot
# 7. Color palletes of plot
# 8. style of the plot
# 9. How do you interpret

# %%
df =sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# scatter plot 
# scatter plot size of figure size
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='age', y='fare' ,hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
# scatter plot 
# scatter plot size of figure size
plt.figure(figsize=(10,6))
palette ={'male': 'blue', 'female':'red'}
sns.scatterplot(data=df, x='age', y='fare' ,hue='sex', palette=palette)
# change the color
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
# import os
# import matplotlib.pyplot as plt
# import seaborn as sns
# import pandas as pd

# # Assuming df is your DataFrame and has 'age', 'fare', and 'sex' columns
# # df = pd.read_csv('your_data.csv')  # Load your data here

# # Define the path where you want to save the plot
# save_dir = './outputs/plots/'

# # Create the directory if it doesn't exist
# os.makedirs(save_dir, exist_ok=True)

# # Scatter plot
# plt.figure(figsize=(8, 4))  # a4 page size 16:
#

# # Define the color palette for the scatter plot
# palette = {'male': 'green', 'female': 'red'}

# # Create the scatter plot with hue based on 'sex'
# sns.scatterplot(data=df, x='age', y='fare', hue='sex', palette=palette)

# # Labels
# plt.xlabel('Age')
# plt.ylabel('Fare')
# plt.title('Scatter Plot of Age vs Fare')

# # Save the plot as a PNG file
# plt.savefig(os.path.join(save_dir, 'scatter_plot_zz.png'), dpi=300)

# # Save the plot as a vector file (SVG)
# plt.savefig(os.path.join(save_dir, 'scatter_plot_zz.svg'))

# # Show the plot
# plt.show()

# %%
# scatter plot
# scatter plot size of figure size
plt.figure(figsize=(8,4)) # a4 page size 16:9

# change the scatter point colors
palette = {'male': 'green', 'female': 'red'}
sns.scatterplot(data=df, x='age', y='fare', hue='sex', palette=palette)
# labels
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Scatter Plot of Age vs Fare')

# saving a plot 300dpi, 600dpi, 150dpi png
plt.savefig('./outputs/plots/scatter_plot_zz.png', dpi=300)

# saving a plot in vector file such as svg
plt.savefig('./outputs/plots/scatter_plot_zz.svg')

# %%
# style of a plot
sns.set_theme(style='darkgrid', font_scale=1.5, font='Times New Roman')
# scatter plot size of figure size
plt.figure(figsize=(16,6)) # a4 page size 16:9

# change the scatter point colors
palette = {'male': 'green', 'female': 'red'}
sns.scatterplot(data=df, x='age', y='fare', hue='sex', size='age', palette=palette)
# labels
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Scatter Plot of Age vs Fare')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Age vs Fare')

# %% [markdown]
# Interpertation
# 1. we have age of passengers at x-axis and fare at y-axis
# 2. The scatter plot show the relationship between age and fare of titanic passengers
# 3. we further grouped the passengers by their genders such as male (Green Point) &&  female(Red points).
# 4. Two male passengers gave the higest fare in titanic and they might be travelling first class.
# 5. the olderst person at titanic is also a male  having 80 years of age as show in the scatter plot .(As show on figure . 1)

# %% [markdown]
# # Box plot

# %%
# style of a plot
sns.set_theme(style='darkgrid', font_scale=1, font='Times New Roman')
# scatter plot size of figure size
plt.figure(figsize=(12,6)) # a4 page size 16:9

# change the scatter point colors
palette = {'First': 'green', 'Second': 'red', 'Third': 'blue'}
sns.boxplot(data=df, x='sex', y='age', hue='class', palette=palette)
# labels
plt.xlabel('Gender')
plt.ylabel('Age')
plt.title('Box plot of Age, based on Gender and Class Name of Passengers')

# change legend position and title
plt.legend(loc='upper right', title='Class Name')

# %%
# style of a plot
sns.set_theme(style='darkgrid', font_scale=1, font='Times New Roman')
# scatter plot size of figure size
plt.figure(figsize=(12,6)) # a4 page size 16:9

# change the scatter point colors
palette = {'First': 'green', 'Second': 'red', 'Third': 'blue'}
sns.boxenplot(data=df, x='sex', y='age', hue='class', palette=palette)
# labels
plt.xlabel('Gender')
plt.ylabel('Age')
plt.title('Box plot of Age, based on Gender and Class Name of Passengers')

# change legend position and title
plt.legend(loc='upper right', title='Class Name')

# change the x tick labels
plt.xticks(ticks=[0, 1], labels=["Male", "Female"])
# Out:
# ([<matplotlib.axis.XTick at 0x1bfc7438980>,
#   <matplotlib.axis.XTick at 0x1bfc74389b0>],
#  [Text(0, 0, 'Male'), Text(1, 0, 'Female')])

# %%
import plotly.express as px

fig =px.scatter(df, x='age', y='fare', color='sex')
fig.show()

# %%
# barplot 
# style of a plot
sns.set_theme(style='darkgrid', font_scale=1, font='Times New Roman')
# scatter plot size of figure size
plt.figure(figsize=(12,6)) # a4 page size 16:9

# change the scatter point colors
palette = {'First': 'green', 'Second': 'red', 'Third': 'blue'}
sns.barplot(data=df, x='sex', y='age', hue='class', palette=palette)
# labels
plt.xlabel('Gender')
plt.ylabel('Age')
plt.title('Bar plot of Age, based on Gender and Class Name of Passengers')

# change legend position and title
plt.legend(loc='upper right', title='Class Name')

# change the x tick labels
plt.xticks(ticks=[0, 1], labels=["Male", "Female"])
# Out:
# ([<matplotlib.axis.XTick at 0x1bfcca28770>,
#   <matplotlib.axis.XTick at 0x1bfcca29f10>],
#  [Text(0, 0, 'Male'), Text(1, 0, 'Female')])

# %%
# bar plot using seaborn

# style of a plot
sns.set_theme(style='darkgrid', font_scale=1, font='Times New Roman')
# scatter plot size of figure size
plt.figure(figsize=(12,6)) # a4 page size 16:9

# change the scatter point colors
palette = {'First': 'green', 'Second': 'red', 'Third': 'blue'}
sns.violinplot(data=df, x='sex', y='age', hue='class', palette=palette)
# labels
plt.xlabel('Gender')
plt.ylabel('Age')
plt.title('Bar plot of Age, based on Gender and Class Name of Passengers')

# change legend position and title
plt.legend(loc='upper right', title='Class Name')

# change the x-ticks names
plt.xticks(ticks=[0, 1], labels=["Male", "Female"], rotation=0)
# Out:
# ([<matplotlib.axis.XTick at 0x1bfccafa690>,
#   <matplotlib.axis.XTick at 0x1bfccaf9ca0>],
#  [Text(0, 0, 'Male'), Text(1, 0, 'Female')])

# %%
import matplotlib.pyplot as plt
import numpy as np

import matplotlib as mpl

th = np.linspace(0, 2*np.pi, 128)


def demo(sty):
    mpl.style.use(sty)
    fig, ax = plt.subplots(figsize=(3, 3))

    ax.set_title(f'style: {sty!r}', color='C0')

    ax.plot(th, np.cos(th), 'C1', label='C1')
    ax.plot(th, np.sin(th), 'C2', label='C2')
    ax.legend()


demo('default')
demo('seaborn-v0_8')

# %%
import matplotlib.colors as mcolors
import matplotlib.patches as mpatch

overlap = {name for name in mcolors.CSS4_COLORS
           if f'xkcd:{name}' in mcolors.XKCD_COLORS}

fig = plt.figure(figsize=[9, 5])
ax = fig.add_axes([0, 0, 1, 1])

n_groups = 3
n_rows = len(overlap) // n_groups + 1

for j, color_name in enumerate(sorted(overlap)):
    css4 = mcolors.CSS4_COLORS[color_name]
    xkcd = mcolors.XKCD_COLORS[f'xkcd:{color_name}'].upper()

    # Pick text colour based on perceived luminance.
    rgba = mcolors.to_rgba_array([css4, xkcd])
    luma = 0.299 * rgba[:, 0] + 0.587 * rgba[:, 1] + 0.114 * rgba[:, 2]
    css4_text_color = 'k' if luma[0] > 0.5 else 'w'
    xkcd_text_color = 'k' if luma[1] > 0.5 else 'w'

    col_shift = (j // n_rows) * 3
    y_pos = j % n_rows
    text_args = dict(fontsize=10, weight='bold' if css4 == xkcd else None)
    ax.add_patch(mpatch.Rectangle((0 + col_shift, y_pos), 1, 1, color=css4))
    ax.add_patch(mpatch.Rectangle((1 + col_shift, y_pos), 1, 1, color=xkcd))
    ax.text(0.5 + col_shift, y_pos + .7, css4,
            color=css4_text_color, ha='center', **text_args)
    ax.text(1.5 + col_shift, y_pos + .7, xkcd,
            color=xkcd_text_color, ha='center', **text_args)
    ax.text(2 + col_shift, y_pos + .7, f'  {color_name}', **text_args)

for g in range(n_groups):
    ax.hlines(range(n_rows), 3*g, 3*g + 2.8, color='0.7', linewidth=1)
    ax.text(0.5 + 3*g, -0.3, 'X11/CSS4', ha='center')
    ax.text(1.5 + 3*g, -0.3, 'xkcd', ha='center')

ax.set_xlim(0, 3 * n_groups)
ax.set_ylim(n_rows, -1)
ax.axis('off')

plt.show()
